# %% [markdown]
# **Zadanie 2. (3.5)**
#
# Zastosuj poniższe przekształcenie dla dowolnego obrazka (np. powyższego łuku). Dobrym pomysłem jest przekształcenie obrazu wejściowego do postaci zmiennoprzecinkowej (float). Warto zwrócić uwagę, że niektóre wartosci mogą przekroczyć 1 - należy je przyciąć.
#
#
# $$
# \begin{bmatrix}
#     R \\
#     G \\
#     B \\
# \end{bmatrix}
# =
# \begin{bmatrix}
#     0.393 & 0.769 & 0.189 \\
#     0.349 & 0.689 & 0.168 \\
#     0.272 & 0.534 & 0.131
# \end{bmatrix}
# \begin{bmatrix}
#     R \\
#     G \\
#     B \\
# \end{bmatrix}
# $$

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (18,10)  # Ustawienie rozmarów wyświetlanych obrazów

image = cv.imread("images/example.jpg")
image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_copy = image.astype(float)

matrix = [
    [0.393, 0.769, 0.189],
    [0.349, 0.689, 0.168],
    [0.272, 0.534, 0.131],
]
matrix = np.asarray(matrix)

for c in range(0,3):
    image_copy[:, :, c] = image_copy[:, :, c]/255

image_copy = np.dot(image_copy, matrix.transpose(), None)
image_copy = np.clip(image_copy, 0, 1)

fig, ax = plt.subplots(1, 2)
ax[0].imshow(image)
ax[1].imshow(image_copy)
